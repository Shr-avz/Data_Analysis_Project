# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/India_energy_data.csv")

# %%
df
# Out:
#     iso_code country  year  coal_prod_change_pct  coal_prod_change_twh  \
# 0        IND   India  1900                   NaN                   NaN
# 1        IND   India  1901                 8.446                 3.340
# 2        IND   India  1902                11.897                 5.102
# 3        IND   India  1903                 0.172                 0.083
# 4        IND   India  1904                10.482                 5.039
# ..       ...     ...   ...                   ...                   ...
# 117      IND   India  2017                 0.846                27.922
# 118      IND   India  2018                 6.775               225.592
# 119      IND   India  2019                -1.584               -56.333
# 120      IND   India  2020                 0.685                23.954
# 121      IND   India  2021                   NaN                   NaN
#
#      gas_prod_change_pct  gas_prod_change_twh  oil_prod_change_pct  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                0.000               32.639
# 2                    NaN                0.000               13.089
# 3                    NaN                0.000               55.093
# 4                    NaN                0.000               34.627
# ..                   ...                  ...                  ...
# 117                4.180               11.110                0.534
# 118               -0.724               -2.004               -2.201
# 119               -2.135               -5.869               -4.881
# 120              -11.691              -31.454               -6.565
# 121                  NaN                  NaN                  NaN
#
#      oil_prod_change_twh  energy_cons_change_pct  ...  solar_consumption  \
# 0                    NaN                     NaN  ...                NaN
# 1                  0.547                     NaN  ...                NaN
# 2                  0.291                     NaN  ...                NaN
# 3                  1.384                     NaN  ...                NaN
# 4                  1.349                     NaN  ...                NaN
# ..                   ...                     ...  ...                ...
# 117                2.499                   3.959  ...             53.861
# 118              -10.351                   6.415  ...             90.297
# 119              -22.448                   2.275  ...            114.569
# 120              -28.723                  -5.629  ...            144.779
# 121                  NaN                     NaN  ...                NaN
#
#      solar_elec_per_capita  solar_energy_per_capita  wind_share_elec  \
# 0                      NaN                      NaN              NaN
# 1                      NaN                      NaN              NaN
# 2                      NaN                      NaN              NaN
# 3                      NaN                      NaN              NaN
# 4                      NaN                      NaN              NaN
# ..                     ...                      ...              ...
# 117                 16.091                   40.235            3.577
# 118                 26.859                   66.756            3.820
# 119                 33.862                   83.846            3.948
# 120                 42.522                  104.912            3.873
# 121                 49.045                      NaN            4.012
#
#      wind_cons_change_pct  wind_share_energy  wind_cons_change_twh  \
# 0                     NaN                NaN                   NaN
# 1                     NaN                NaN                   NaN
# 2                     NaN                NaN                   NaN
# 3                     NaN                NaN                   NaN
# 4                     NaN                NaN                   NaN
# ..                    ...                ...                   ...
# 117                20.396              1.521                22.288
# 118                13.935              1.628                18.334
# 119                 4.592              1.665                 6.884
# 120                -4.910              1.678                -7.698
# 121                   NaN                NaN                   NaN
#
#      wind_consumption  wind_elec_per_capita  wind_energy_per_capita
# 0                 NaN                   NaN                     NaN
# 1                 NaN                   NaN                     NaN
# 2                 NaN                   NaN                     NaN
# 3                 NaN                   NaN                     NaN
# 4                 NaN                   NaN                     NaN
# ..                ...                   ...                     ...
# 117           131.562                39.307                  98.278
# 118           149.896                44.587                 110.817
# 119           156.780                46.333                 114.738
# 120           149.082                43.790                 108.030
# 121               NaN                48.859                     NaN
#
# [122 rows x 128 columns]

# %%
num_duplicates = df.duplicated().sum()
num_duplicates
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# iso_code                   0
# country                    0
# year                       0
# coal_prod_change_pct       2
# coal_prod_change_twh       2
#                           ..
# wind_share_energy         66
# wind_cons_change_twh      67
# wind_consumption          66
# wind_elec_per_capita      65
# wind_energy_per_capita    66
# Length: 128, dtype: int64

# %%
print(df.dtypes)
# Out:
# iso_code                   object
# country                    object
# year                        int64
# coal_prod_change_pct      float64
# coal_prod_change_twh      float64
#                            ...
# wind_share_energy         float64
# wind_cons_change_twh      float64
# wind_consumption          float64
# wind_elec_per_capita      float64
# wind_energy_per_capita    float64
# Length: 128, dtype: object

# %%
for column in df.columns:
    print(f"{column}: {df[column].dtype}")
# Out:
# iso_code: object
# country: object
# year: int64
# coal_prod_change_pct: float64
# coal_prod_change_twh: float64
# gas_prod_change_pct: float64
# gas_prod_change_twh: float64
# oil_prod_change_pct: float64
# oil_prod_change_twh: float64
# energy_cons_change_pct: float64
# energy_cons_change_twh: float64
# biofuel_share_elec: float64
# biofuel_elec_per_capita: float64
# biofuel_cons_change_pct: float64
# biofuel_share_energy: float64
# biofuel_cons_change_twh: float64
# biofuel_consumption: float64
# biofuel_cons_per_capita: float64
# carbon_intensity_elec: float64
# coal_share_elec: float64
# coal_cons_change_pct: float64
# coal_share_energy: float64
# coal_cons_change_twh: float64
# coal_consumption: float64
# coal_elec_per_capita: float64
# coal_cons_per_capita: float64
# coal_production: float64
# coal_prod_per_capita: float64
# electricity_demand: float64
# biofuel_electricity: float64
# coal_electricity: float64
# fossil_electricity: float64
# gas_electricity: float64
# hydro_electricity: float64
# nuclear_electricity: float64
# oil_electricity: float64
# other_renewable_exc_biofuel_electricity: float64
# other_renewable_electricity: float64
# renewables_electricity: float64
# solar_electricity: float64
# wind_electricity: float64
# electricity_generation: float64
# greenhouse_gas_emissions: float64
# energy_per_gdp: float64
# energy_per_capita: float64
# fossil_cons_change_pct: float64
# fossil_share_energy: float64
# fossil_cons_change_twh: float64
# fossil_fuel_consumption: float64
# fossil_energy_per_capita: float64
# fossil_cons_per_capita: float64
# fossil_share_elec: float64
# gdp: float64
# gas_share_elec: float64
# gas_cons_change_pct: float64
# gas_share_energy: float64
# gas_cons_change_twh: float64
# gas_consumption: float64
# gas_elec_per_capita: float64
# gas_energy_per_capita: float64
# gas_production: float64
# gas_prod_per_capita: float64
# hydro_share_elec: float64
# hydro_cons_change_pct: float64
# hydro_share_energy: float64
# hydro_cons_change_twh: float64
# hydro_consumption: float64
# hydro_elec_per_capita: float64
# hydro_energy_per_capita: float64
# low_carbon_share_elec: float64
# low_carbon_electricity: float64
# low_carbon_elec_per_capita: float64
# low_carbon_cons_change_pct: float64
# low_carbon_share_energy: float64
# low_carbon_cons_change_twh: float64
# low_carbon_consumption: float64
# low_carbon_energy_per_capita: float64
# net_elec_imports_share_demand: float64
# net_elec_imports: float64
# nuclear_share_elec: float64
# nuclear_cons_change_pct: float64
# nuclear_share_energy: float64
# nuclear_cons_change_twh: float64
# nuclear_consumption: float64
# nuclear_elec_per_capita: float64
# nuclear_energy_per_capita: float64
# oil_share_elec: float64
# oil_cons_change_pct: float64
# oil_share_energy: float64
# oil_cons_change_twh: float64
# oil_consumption: float64
# oil_elec_per_capita: float64
# oil_energy_per_capita: float64
# oil_production: float64
# oil_prod_per_capita: float64
# other_renewables_elec_per_capita_exc_biofuel: float64
# other_renewables_elec_per_capita: float64
# other_renewables_cons_change_pct: float64
# other_renewables_share_energy: float64
# other_renewables_cons_change_twh: float64
# other_renewable_consumption: float64
# other_renewables_share_elec_exc_biofuel: float64
# other_renewables_share_elec: float64
# other_renewables_energy_per_capita: float64
# per_capita_electricity: float64
# population: float64
# primary_energy_consumption: float64
# renewables_elec_per_capita: float64
# renewables_share_elec: float64
# renewables_cons_change_pct: float64
# renewables_share_energy: float64
# renewables_cons_change_twh: float64
# renewables_consumption: float64
# renewables_energy_per_capita: float64
# solar_share_elec: float64
# solar_cons_change_pct: float64
# solar_share_energy: float64
# solar_cons_change_twh: float64
# solar_consumption: float64
# solar_elec_per_capita: float64
# solar_energy_per_capita: float64
# wind_share_elec: float64
# wind_cons_change_pct: float64
# wind_share_energy: float64
# wind_cons_change_twh: float64
# wind_consumption: float64
# wind_elec_per_capita: float64
# wind_energy_per_capita: float64

# %%
df = df.fillna('')

# %%
df
# Out:
#     iso_code country  year coal_prod_change_pct coal_prod_change_twh  \
# 0        IND   India  1900
# 1        IND   India  1901                8.446                 3.34
# 2        IND   India  1902               11.897                5.102
# 3        IND   India  1903                0.172                0.083
# 4        IND   India  1904               10.482                5.039
# ..       ...     ...   ...                  ...                  ...
# 117      IND   India  2017                0.846               27.922
# 118      IND   India  2018                6.775              225.592
# 119      IND   India  2019               -1.584              -56.333
# 120      IND   India  2020                0.685               23.954
# 121      IND   India  2021
#
#     gas_prod_change_pct gas_prod_change_twh oil_prod_change_pct  \
# 0
# 1                                       0.0              32.639
# 2                                       0.0              13.089
# 3                                       0.0              55.093
# 4                                       0.0              34.627
# ..                  ...                 ...                 ...
# 117                4.18               11.11               0.534
# 118              -0.724              -2.004              -2.201
# 119              -2.135              -5.869              -4.881
# 120             -11.691             -31.454              -6.565
# 121
#
#     oil_prod_change_twh energy_cons_change_pct  ... solar_consumption  \
# 0                                               ...
# 1                 0.547                         ...
# 2                 0.291                         ...
# 3                 1.384                         ...
# 4                 1.349                         ...
# ..                  ...                    ...  ...               ...
# 117               2.499                  3.959  ...            53.861
# 118             -10.351                  6.415  ...            90.297
# 119             -22.448                  2.275  ...           114.569
# 120             -28.723                 -5.629  ...           144.779
# 121                                             ...
#
#     solar_elec_per_capita solar_energy_per_capita wind_share_elec  \
# 0
# 1
# 2
# 3
# 4
# ..                    ...                     ...             ...
# 117                16.091                  40.235           3.577
# 118                26.859                  66.756            3.82
# 119                33.862                  83.846           3.948
# 120                42.522                 104.912           3.873
# 121                49.045                                   4.012
#
#     wind_cons_change_pct wind_share_energy wind_cons_change_twh  \
# 0
# 1
# 2
# 3
# 4
# ..                   ...               ...                  ...
# 117               20.396             1.521               22.288
# 118               13.935             1.628               18.334
# 119                4.592             1.665                6.884
# 120                -4.91             1.678               -7.698
# 121
#
#     wind_consumption wind_elec_per_capita wind_energy_per_capita
# 0
# 1
# 2
# 3
# 4
# ..               ...                  ...                    ...
# 117          131.562               39.307                 98.278
# 118          149.896               44.587                110.817
# 119           156.78               46.333                114.738
# 120          149.082                43.79                 108.03
# 121                                48.859
#
# [122 rows x 128 columns]

# %%
df = df.apply(pd.to_numeric, errors='coerce')

# %%
median_values = df.median()

# %%
print("Median values for each column:")
print(median_values)
# Out:
# Median values for each column:
# iso_code                        NaN
# country                         NaN
# year                      1960.5000
# coal_prod_change_pct         4.0505
# coal_prod_change_twh        10.4785
#                             ...
# wind_share_energy            0.0115
# wind_cons_change_twh         0.0000
# wind_consumption             0.2885
# wind_elec_per_capita         0.1270
# wind_energy_per_capita       0.3180
# Length: 128, dtype: float64

# %%
df.fillna(median_values,inplace=True)

# %%
df
# Out:
#      iso_code  country  year  coal_prod_change_pct  coal_prod_change_twh  \
# 0         NaN      NaN  1900                4.0505               10.4785
# 1         NaN      NaN  1901                8.4460                3.3400
# 2         NaN      NaN  1902               11.8970                5.1020
# 3         NaN      NaN  1903                0.1720                0.0830
# 4         NaN      NaN  1904               10.4820                5.0390
# ..        ...      ...   ...                   ...                   ...
# 117       NaN      NaN  2017                0.8460               27.9220
# 118       NaN      NaN  2018                6.7750              225.5920
# 119       NaN      NaN  2019               -1.5840              -56.3330
# 120       NaN      NaN  2020                0.6850               23.9540
# 121       NaN      NaN  2021                4.0505               10.4785
#
#      gas_prod_change_pct  gas_prod_change_twh  oil_prod_change_pct  \
# 0                 8.9355                0.000               3.1615
# 1                 8.9355                0.000              32.6390
# 2                 8.9355                0.000              13.0890
# 3                 8.9355                0.000              55.0930
# 4                 8.9355                0.000              34.6270
# ..                   ...                  ...                  ...
# 117               4.1800               11.110               0.5340
# 118              -0.7240               -2.004              -2.2010
# 119              -2.1350               -5.869              -4.8810
# 120             -11.6910              -31.454              -6.5650
# 121               8.9355                0.000               3.1615
#
#      oil_prod_change_twh  energy_cons_change_pct  ...  solar_consumption  \
# 0                  0.407                   5.297  ...              0.000
# 1                  0.547                   5.297  ...              0.000
# 2                  0.291                   5.297  ...              0.000
# 3                  1.384                   5.297  ...              0.000
# 4                  1.349                   5.297  ...              0.000
# ..                   ...                     ...  ...                ...
# 117                2.499                   3.959  ...             53.861
# 118              -10.351                   6.415  ...             90.297
# 119              -22.448                   2.275  ...            114.569
# 120              -28.723                  -5.629  ...            144.779
# 121                0.407                   5.297  ...              0.000
#
#      solar_elec_per_capita  solar_energy_per_capita  wind_share_elec  \
# 0                    0.000                    0.000            0.407
# 1                    0.000                    0.000            0.407
# 2                    0.000                    0.000            0.407
# 3                    0.000                    0.000            0.407
# 4                    0.000                    0.000            0.407
# ..                     ...                      ...              ...
# 117                 16.091                   40.235            3.577
# 118                 26.859                   66.756            3.820
# 119                 33.862                   83.846            3.948
# 120                 42.522                  104.912            3.873
# 121                 49.045                    0.000            4.012
#
#      wind_cons_change_pct  wind_share_energy  wind_cons_change_twh  \
# 0                 16.3895             0.0115                 0.000
# 1                 16.3895             0.0115                 0.000
# 2                 16.3895             0.0115                 0.000
# 3                 16.3895             0.0115                 0.000
# 4                 16.3895             0.0115                 0.000
# ..                    ...                ...                   ...
# 117               20.3960             1.5210                22.288
# 118               13.9350             1.6280                18.334
# 119                4.5920             1.6650                 6.884
# 120               -4.9100             1.6780                -7.698
# 121               16.3895             0.0115                 0.000
#
#      wind_consumption  wind_elec_per_capita  wind_energy_per_capita
# 0              0.2885                 0.127                   0.318
# 1              0.2885                 0.127                   0.318
# 2              0.2885                 0.127                   0.318
# 3              0.2885                 0.127                   0.318
# 4              0.2885                 0.127                   0.318
# ..                ...                   ...                     ...
# 117          131.5620                39.307                  98.278
# 118          149.8960                44.587                 110.817
# 119          156.7800                46.333                 114.738
# 120          149.0820                43.790                 108.030
# 121            0.2885                48.859                   0.318
#
# [122 rows x 128 columns]

# %%
excel_file_path = 'output.xlsx'

# %%
df.to_excel(excel_file_path,index=False)

# %%
print("Dataset copied to Excel sucessfully")
# Out:
# Dataset copied to Excel sucessfully
