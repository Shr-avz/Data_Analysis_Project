# %%
import pandas as pd

# %%
df1 = pd.read_csv('/content/iceland updated data.csv')

# %%
df2 = pd.read_csv('/content/india updated data.csv')

# %%
df3 = pd.read_csv('/content/indonesia updated data.csv')

# %%
df1
# Out:
#    iso_code  country  year  coal_prod_change_pct  coal_prod_change_twh  \
# 0       ISL  Iceland  1965                     0                     0
# 1       ISL  Iceland  1966                     0                     0
# 2       ISL  Iceland  1967                     0                     0
# 3       ISL  Iceland  1968                     0                     0
# 4       ISL  Iceland  1969                     0                     0
# 5       ISL  Iceland  1970                     0                     0
# 6       ISL  Iceland  1971                     0                     0
# 7       ISL  Iceland  1972                     0                     0
# 8       ISL  Iceland  1973                     0                     0
# 9       ISL  Iceland  1974                     0                     0
# 10      ISL  Iceland  1975                     0                     0
# 11      ISL  Iceland  1976                     0                     0
# ...

# %%
merged_df = pd.concat([df1,df2,df3],ignore_index=True)

# %%
print(merged_df)
# Out:
#     iso_code    country    year  coal_prod_change_pct  coal_prod_change_twh  \
# 0        ISL    Iceland  1965.0                 0.000                 0.000
# 1        ISL    Iceland  1966.0                 0.000                 0.000
# 2        ISL    Iceland  1967.0                 0.000                 0.000
# 3        ISL    Iceland  1968.0                 0.000                 0.000
# 4        ISL    Iceland  1969.0                 0.000                 0.000
# ..       ...        ...     ...                   ...                   ...
# 295      IDN  Indonesia  2017.0                 1.107                34.611
# 296      IDN  Indonesia  2018.0                20.927               661.493
# 297      IDN  Indonesia  2019.0                10.468               400.129
# 298      IDN  Indonesia  2020.0                -8.704              -367.529
# 299    Total        NaN     NaN                   NaN                   NaN
#
# ...

# %%
excel_file_path = 'output.xlsx'

# %%
merged_df.to_excel(excel_file_path,index=False)

# %%
print("Dataset copied to Excel sucessfully")
# Out:
# Dataset copied to Excel sucessfully

# %%
merged_df.shape
# Out:
# (300, 128)

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Columns: 128 entries, iso_code to wind_energy_per_capita
# dtypes: float64(126), object(2)
# memory usage: 300.1+ KB

# %%
merged_df.isnull().sum()
# Out:
# iso_code                  0
# country                   1
# year                      1
# coal_prod_change_pct      1
# coal_prod_change_twh      1
#                          ..
# wind_share_energy         1
# wind_cons_change_twh      1
# wind_consumption          1
# wind_elec_per_capita      1
# wind_energy_per_capita    1
# Length: 128, dtype: int64

# %%
df= pd.read_csv('/content/FINAL DATA - COMPAILED.csv')

# %%
df.isnull().sum()
# Out:
# sl_no                     0
# iso_code                  0
# country                   0
# year                      0
# coal_prod_change_pct      0
#                          ..
# wind_share_energy         0
# wind_cons_change_twh      0
# wind_consumption          0
# wind_elec_per_capita      0
# wind_energy_per_capita    0
# Length: 129, dtype: int64

# %%
df.nunique()
# Out:
# sl_no                     299
# iso_code                    3
# country                     3
# year                      122
# coal_prod_change_pct      236
#                          ...
# wind_share_energy          43
# wind_cons_change_twh       47
# wind_consumption           47
# wind_elec_per_capita       43
# wind_energy_per_capita     53
# Length: 129, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Columns: 129 entries, sl_no to wind_energy_per_capita
# dtypes: float64(124), int64(3), object(2)
# memory usage: 301.5+ KB

# %%
num_duplicates = df.duplicated().sum()
num_duplicates
# Out:
# 0

# %%
df
# Out:
#      sl_no iso_code    country  year  coal_prod_change_pct  \
# 0        1      ISL    Iceland  1965                 0.000
# 1        2      ISL    Iceland  1966                 0.000
# 2        3      ISL    Iceland  1967                 0.000
# 3        4      ISL    Iceland  1968                 0.000
# 4        5      ISL    Iceland  1969                 0.000
# ..     ...      ...        ...   ...                   ...
# 294    295      IDN  Indonesia  2016                -1.163
# 295    296      IDN  Indonesia  2017                 1.107
# 296    297      IDN  Indonesia  2018                20.927
# 297    298      IDN  Indonesia  2019                10.468
# 298    299      IDN  Indonesia  2020                -8.704
#
#      coal_prod_change_twh  gas_prod_change_pct  gas_prod_change_twh  \
# 0                   0.000                0.000                0.000
# 1                   0.000                0.000                0.000
# ...

# %%
df['primary_energy_consumption'] = df['primary_energy_consumption'].replace('[^0-9.]', '', regex=True).astype(float)

# %%
df['energy_per_capita'] = df['energy_per_capita'].replace('[^0-9.]', '', regex=True).astype(float)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='primary_energy_consumption', data=df)
plt.title('Boxplot of Amount to Identify Outliers')
plt.show()

# %%
print(df['primary_energy_consumption'].describe())
# Out:
# count     299.000000
# mean     1544.837559
# std      1714.220887
# min         7.468000
# 25%       367.026500
# 50%       748.919000
# 75%      2571.424000
# max      9414.266000
# Name: primary_energy_consumption, dtype: float64

# %%
Q1 = df['primary_energy_consumption'].quantile(0.25)
Q3 = df['primary_energy_consumption'].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = (df['primary_energy_consumption'] < lower_bound) | (df['primary_energy_consumption'] > upper_bound)

# Count the number of outliers
num_outliers = outliers.sum()

print(f"Number of outliers: {num_outliers}")
# Out:
# Number of outliers: 12

# %%
df = df[~outliers]

# %%
data=df

# %%
new_df=df.groupby("iso_code").agg({"primary_energy_consumption":["sum","mean"]})

# %%
new_df
# Out:
#          primary_energy_consumption
#                                 sum         mean
# iso_code
# IDN                      100087.921   827.172901
# IND                      267049.345  2427.721318
# ISL                        1614.636    28.832786

# %%
df.isna()
# Out:
#      sl_no  iso_code  country   year  coal_prod_change_pct  \
# 0    False     False    False  False                 False
# 1    False     False    False  False                 False
# 2    False     False    False  False                 False
# 3    False     False    False  False                 False
# 4    False     False    False  False                 False
# ..     ...       ...      ...    ...                   ...
# 294  False     False    False  False                 False
# 295  False     False    False  False                 False
# 296  False     False    False  False                 False
# 297  False     False    False  False                 False
# 298  False     False    False  False                 False
#
#      coal_prod_change_twh  gas_prod_change_pct  gas_prod_change_twh  \
# 0                   False                False                False
# 1                   False                False                False
# ...

# %%
sum(data["primary_energy_consumption"].isna())
# Out:
# 0

# %%
df["primary_energy_consumption"].fillna(0)
# Out:
# 0         7.468
# 1         7.840
# 2         7.760
# 3         8.211
# 4         8.168
#          ...
# 294    1992.624
# 295    2075.650
# 296    2241.485
# 297    2403.714
# 298    2120.519
# Name: primary_energy_consumption, Length: 287, dtype: float64

# %%
df["primary_energy_consumption"] = df["primary_energy_consumption"].fillna(0)
# Out:
# <ipython-input-41-d86db1675ce6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["primary_energy_consumption"] = df["primary_energy_consumption"].fillna(0)

# %%
df['primary_energy_consumption'].describe()
# Out:
# count     287.000000
# mean     1284.849833
# std      1148.551882
# min         7.468000
# 25%       312.988500
# 50%       748.919000
# 75%      2571.424000
# max      5542.541000
# Name: primary_energy_consumption, dtype: float64

# %%
df[df["primary_energy_consumption"] == "ISL"]
# Out:
# Empty DataFrame
# ...

# %%
df = df[df["primary_energy_consumption"] != "ISL"]

# %%
df["primary_energy_consumption"] = df["primary_energy_consumption"].replace("ISL", 0)

# %%
df = df[df["primary_energy_consumption"].apply(lambda x: type(x) != str)]

# %%
df["primary_energy_consumption"] = pd.to_numeric(df["primary_energy_consumption"])

# %%
df["primary_energy_consumption"] = df["primary_energy_consumption"].replace("ISL", 0)

# %%
df[df["primary_energy_consumption"] == "ISL"]
# Out:
# Empty DataFrame
# ...

# %%
df["primary_energy_consumption"] = pd.to_numeric(df["primary_energy_consumption"], errors="coerce")

# %%
df = df[df["primary_energy_consumption"] != "ISL"]

# %%
df["primary_energy_consumption"] = pd.to_numeric(df["primary_energy_consumption"], errors="coerce")

# %%
# Calculate the number of rows before and after removing outliers
rows_before = len(df)
rows_after = len(df_cleaned)

# Calculate the percentage of data loss
data_loss_percentage = ((rows_before - rows_after) / rows_before) * 100

print(f"Data loss percentage: {data_loss_percentage:.2f}%")
# Out:
# Data loss percentage: 1.05%

# %%
import numpy as np
from scipy.stats import zscore

# Calculate Z-scores
df['z_score'] = zscore(df['primary_energy_consumption'])

# Set a threshold for identifying outliers (e.g., 3 standard deviations)
threshold = 3

# Identify outliers
outliers = df[np.abs(df['z_score']) > threshold]

# Remove outliers
df_cleaned = df[np.abs(df['z_score']) <= threshold]

# %%
import pandas as pd


# Set trimming percentage
trimming_percentage = 0.05

# Calculate the number of rows to trim from each end
n_trim = int(len(df) * trimming_percentage)

# Calculate statistics before trimming
total_records_before = len(df)
mean_before = df['primary_energy_consumption'].mean()
std_before = df['primary_energy_consumption'].std()
max_before = df['primary_energy_consumption'].max()

# Sort the DataFrame by the 'primary_energy_consumption' column
df_sorted = df.sort_values(by='primary_energy_consumption')

# Trim the top and bottom 5% of the rows
df_trimmed = df_sorted.iloc[n_trim:-n_trim]

# Reset the index of the trimmed DataFrame
df_trimmed.reset_index(drop=True, inplace=True)

# Calculate statistics after trimming
total_records_after = len(df_trimmed)
mean_after = df_trimmed['primary_energy_consumption'].mean()
std_after = df_trimmed['primary_energy_consumption'].std()
max_after = df_trimmed['primary_energy_consumption'].max()

# Print statistics before and after trimming
print(f"Statistics before trimming:")
print(f"Total records: {total_records_before}")
print(f"Mean: {mean_before}")
print(f"Standard Deviation: {std_before}")
print(f"Max: {max_before}")

print("\nStatistics after trimming:")
print(f"Total records: {total_records_after}")
print(f"Mean: {mean_after}")
print(f"Standard Deviation: {std_after}")
print(f"Max: {max_after}")
# Out:
# Statistics before trimming:
# Total records: 287
# Mean: 1284.8498327526133
# Standard Deviation: 1148.5518823203636
# Max: 5542.541
#
# Statistics after trimming:
# Total records: 259
# Mean: 1206.8733976833976
# Standard Deviation: 967.2774177416817
# Max: 2742.259

# %%
import pandas as pd


# Calculate the 5th and 95th percentiles
lower_threshold = df['primary_energy_consumption'].quantile(0.05)
upper_threshold = df['primary_energy_consumption'].quantile(0.95)

# Apply capping
df['primary_energy_consumption_capped'] = df['primary_energy_consumption'].clip(lower=lower_threshold, upper=upper_threshold)

# Calculate statistics before capping
total_records_before = len(df)
mean_before = df['primary_energy_consumption'].mean()
std_before = df['primary_energy_consumption'].std()
max_before = df['primary_energy_consumption'].max()

# Calculate statistics after capping
mean_after = df['primary_energy_consumption_capped'].mean()
std_after = df['primary_energy_consumption_capped'].std()
max_after = df['primary_energy_consumption_capped'].max()

# Print statistics before and after capping
print(f"Statistics before capping:")
print(f"Total records: {total_records_before}")
print(f"Mean: {mean_before}")
print(f"Standard Deviation: {std_before}")
print(f"Max: {max_before}")

print("\nStatistics after capping:")
print(f"Total records: {total_records_before}")  # The number of records remains the same
print(f"Mean: {mean_after}")
print(f"Standard Deviation: {std_after}")
print(f"Max: {max_after}")
# Out:
# Statistics before capping:
# Total records: 287
# Mean: 1284.8498327526133
# Standard Deviation: 1148.5518823203636
# Max: 5542.541
#
# Statistics after capping:
# Total records: 287
# Mean: 1221.4812125435537
# Standard Deviation: 1010.9571398686597
# Max: 2700.5049999999983

# %%
# Apply logarithmic transformation (adding 1 to avoid log(0))
df['primary_energy_consumption_log'] = np.log1p(df['primary_energy_consumption'])

# Calculate statistics before transformation
total_records_before = len(df)
mean_before = df['primary_energy_consumption'].mean()
std_before = df['primary_energy_consumption'].std()
max_before = df['primary_energy_consumption'].max()

# Calculate statistics after transformation
mean_after = df['primary_energy_consumption_log'].mean()
std_after = df['primary_energy_consumption_log'].std()
max_after = df['primary_energy_consumption_log'].max()

# Print statistics before and after transformation
print(f"Statistics before transformation:")
print(f"Total records: {total_records_before}")
print(f"Mean: {mean_before}")
print(f"Standard Deviation: {std_before}")
print(f"Max: {max_before}")

print("\nStatistics after transformation:")
print(f"Total records: {total_records_before}")  # The number of records remains the same
print(f"Mean: {mean_after}")
print(f"Standard Deviation: {std_after}")
print(f"Max: {max_after}")
# Out:
# Statistics before transformation:
# Total records: 287
# Mean: 1284.8498327526133
# Standard Deviation: 1148.5518823203636
# Max: 5542.541
#
# Statistics after transformation:
# Total records: 287
# Mean: 6.323737751793051
# Standard Deviation: 1.7389036751540954
# Max: 8.620388745234482

# %%
import pandas as pd
from scipy.stats import mstats


# Define the percentiles for Winsorization
lower_percentile = 0.05
upper_percentile = 0.95

# Apply Winsorization
df['primary_energy_consumption_winsorized'] = mstats.winsorize(df['primary_energy_consumption'], limits=[lower_percentile, upper_percentile])

# Calculate statistics before Winsorization
total_records_before = len(df)
mean_before = df['primary_energy_consumption'].mean()
std_before = df['primary_energy_consumption'].std()
max_before = df['primary_energy_consumption'].max()

# Calculate statistics after Winsorization
mean_after = df['primary_energy_consumption_winsorized'].mean()
std_after = df['primary_energy_consumption_winsorized'].std()
max_after = df['primary_energy_consumption_winsorized'].max()

# Print statistics before and after Winsorization
print(f"Statistics before Winsorization:")
print(f"Total records: {total_records_before}")
print(f"Mean: {mean_before}")
print(f"Standard Deviation: {std_before}")
print(f"Max: {max_before}")

print("\nStatistics after Winsorization:")
print(f"Total records: {total_records_before}")  # The number of records remains the same
print(f"Mean: {mean_after}")
print(f"Standard Deviation: {std_after}")
print(f"Max: {max_after}")
# Out:
# Statistics before Winsorization:
# Total records: 287
# Mean: 1284.8498327526133
# Standard Deviation: 1148.5518823203636
# Max: 5542.541
#
# Statistics after Winsorization:
# Total records: 287
# Mean: 15.623999999999999
# Standard Deviation: 1.779459648471268e-15
# Max: 15.624

# %%
def detect_outliers_iqr(column):
    Q1 = column.quantile(0.25)
    Q3 = column.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return (column < lower_bound) | (column > upper_bound)

# %%
df = df.apply(pd.to_numeric, errors='coerce')

# %%
outliers = df.apply(detect_outliers_iqr)

# %%
outliers_count = outliers.sum()

# %%
print("Number of outliers in each column:")
print(outliers_count)
# Out:
# Number of outliers in each column:
# sl_no                      0
# iso_code                   0
# country                    0
# year                       0
# coal_prod_change_pct      34
#                           ..
# wind_cons_change_twh      48
# wind_consumption          28
# wind_elec_per_capita      36
# wind_energy_per_capita    37
# z_score                   12
# Length: 130, dtype: int64

# %%
import pandas as pd

# Set the maximum number of rows to display
pd.set_option('display.max_rows', None)

# Print the outliers_count DataFrame
print("Number of outliers in each column:")
print(outliers_count)

# Reset the display settings to the default
pd.reset_option('display.max_rows')
# Out:
# Number of outliers in each column:
# sl_no                                             0
# iso_code                                          0
# country                                           0
# year                                              0
# coal_prod_change_pct                             34
# coal_prod_change_twh                             54
# gas_prod_change_pct                              34
# gas_prod_change_twh                              86
# oil_prod_change_pct                              35
# oil_prod_change_twh                              89
# energy_cons_change_pct                           49
# energy_cons_change_twh                           13
# biofuel_share_elec                                0
# biofuel_elec_per_capita                           0
# biofuel_cons_change_pct                           3
# biofuel_share_energy                              8
# biofuel_cons_change_twh                          37
# ...

# %%
print("First 10 rows:")
print(outliers_count.head(10))

print("\nLast 10 rows:")
print(outliers_count.tail(10))
# Out:
# First 10 rows:
# sl_no                    0
# iso_code                 0
# country                  0
# year                     0
# coal_prod_change_pct    34
# coal_prod_change_twh    54
# gas_prod_change_pct     34
# gas_prod_change_twh     86
# oil_prod_change_pct     35
# oil_prod_change_twh     89
# dtype: int64
#
# Last 10 rows:
# solar_elec_per_capita      35
# solar_energy_per_capita    39
# wind_share_elec            16
# wind_cons_change_pct       17
# wind_share_energy          33
# wind_cons_change_twh       48
# wind_consumption           28
# wind_elec_per_capita       36
# wind_energy_per_capita     37
# z_score                    12
# dtype: int64

# %%
correlation = df["gdp"].corr(df["primary_energy_consumption"])

# %%
df4 = pd.read_csv('/content/FINAL DATA - COMPAILED.csv')

# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt

# Load the world map shapefile from Geopandas
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))


# Merge the world map with the energy consumption data
# Ensure the country names in your data match those in the world map shapefile
world = world.rename(columns={'name': 'country'})
world = world.merge(df4, on='country', how='left')

# Plotting
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
world.boundary.plot(ax=ax)
world.plot(column='primary_energy_consumption', ax=ax, legend=True,
           legend_kwds={'label': "primary energy consumption",
                        'orientation': "horizontal"})

# Add title and show plot
plt.title('primary energy consumption by country')
plt.show()
# Out:
# <ipython-input-37-d5a244bf51bb>:6: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
correlation
# Out:
# 0.7720935700194574

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt


# Calculate the correlation coefficient
correlation = df["gdp"].corr(df["primary_energy_consumption"])

# Create a scatter plot with GDP on the x-axis and Primary Energy Consumption on the y-axis
plt.scatter(df["gdp"], df["primary_energy_consumption"])

# Add a title and labels to the axes
plt.title("Correlation between GDP and Primary Energy Consumption")
plt.xlabel("gdp")
plt.ylabel("primary energy consumption")

# Add a text box to display the correlation coefficient
plt.text(0.5, 0.5, f"Correlation: {correlation:.2f}", transform=plt.gca().transAxes, ha="center", va="center")

# Show the plot
plt.show()
